# %%
# %matplotlib inline
import os, sys
import numpy as np
from utils_data_exploration import *
import gc

# %% [markdown]
# ### Directory Structure

# %%
# %pwd # verify you are in the correct folder
# Out:
# '/home/javier/Documents/YelpRestaurantPhotoClassification/nbs'

# %%
# Assign Path Constants
LESSON_HOME_DIR = os.getcwd() # path tho the notebook
DATA_DIR = LESSON_HOME_DIR + '/../data/'
SHARED_PATH = DATA_DIR + 'shared/'

# %% [markdown]
# ### Start with the list of businesses

# %%
businesses_id = np.load(SHARED_PATH+'businesses_shuffled.npy')

# %% [markdown]
# ### Show photos in businesses

# %%
business_id # good for lunch, good for kids
# Out:
# 1583

# %%
business_id = np.random.choice(businesses_id)

# %%
df_train_labels.loc[business_id]['labels']
# Out:
# (0, 5, 8)

# %%
list(map(label_desc_dict.get, df_train_labels.loc[business_id]['labels']))
# Out:
# ['good_for_lunch', 'has_alcohol', 'good_for_kids']

# %%
show_photos_in_bussiness(business_id, m=1, n=6, seed=19)
# Out:
# 6/201 in buisness 1378
# 6/201 in buisness 1378
# 6/201 in buisness 1378
